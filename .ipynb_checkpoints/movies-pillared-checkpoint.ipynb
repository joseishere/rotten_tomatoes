# %% [markdown]
# # Pillared - Movies

# %%
# imports: might not use some but import just in case, yes i knowwww you dont have to tell me
from math import *
import statistics
import numpy as np
import pandas as pd
import queue
import time
import csv
import glob
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from datetime import date

# %%
data = pd.read_csv('clean_data.csv')
display(data)
# Out:
#       Unnamed: 0                                        movie_title  \
# 0              0  Percy Jackson & the Olympians: The Lightning T...
# 1              1                                        Please Give
# 2              3                    12 Angry Men (Twelve Angry Men)
# 3              5                                        10,000 B.C.
# 4              6                                       The 39 Steps
# ...          ...                                                ...
# 5453       17703                                          Zookeeper
# 5454       17704                                          Zoolander
# 5455       17705                                        Zoolander 2
# 5456       17706                                               Zoom
# 5457       17708                                           Zootopia
#
#      content_rating                                             genres  \
# 0                PG  Action & Adventure, Comedy, Drama, Science Fic...
# 1                 R                                             Comedy
# 2                NR                                    Classics, Drama
# 3             PG-13                Action & Adventure, Classics, Drama
# 4                NR   Action & Adventure, Classics, Mystery & Suspense
# ...             ...                                                ...
# 5453             PG                                    Comedy, Romance
# 5454          PG-13                           Comedy, Special Interest
# 5455          PG-13                                             Comedy
# 5456             PG          Action & Adventure, Comedy, Kids & Family
# 5457             PG              Action & Adventure, Animation, Comedy
#
#                                  directors  \
# 0                           Chris Columbus
# 1                        Nicole Holofcener
# 2                             Sidney Lumet
# 3                          Roland Emmerich
# 4                         Alfred Hitchcock
# ...                                    ...
# 5453             Frank Coraci, Walt Becker
# 5454                           Ben Stiller
# 5455                           Ben Stiller
# 5456                          Peter Hewitt
# 5457  Byron Howard, Rich Moore, Jared Bush
#
#                                                  actors original_release_date  \
# 0     Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1     Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2     Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 3     Steven Strait, Camilla Belle, Cliff Curtis, Jo...            2008-03-07
# 4     Robert Donat, Madeleine Carroll, Godfrey Tearl...            1935-08-01
# ...                                                 ...                   ...
# 5453  Kevin James, Rosario Dawson, Ken Jeong, Leslie...            2011-07-08
# 5454  Ben Stiller, Owen Wilson, Will Ferrell, Christ...            2001-09-28
# 5455  Ben Stiller, Owen Wilson, Will Ferrell, Penelo...            2016-02-12
# 5456  Tim Allen, Courteney Cox, Chevy Chase, Spencer...            2006-08-11
# 5457  J.K. Simmons, Kristen Bell, Octavia Spencer, A...            2016-03-04
#
#      streaming_release_date  runtime             production_company  \
# 0                2015-11-25    119.0               20th Century Fox
# 1                2012-09-04     90.0         Sony Pictures Classics
# 2                2017-01-13     95.0           Criterion Collection
# 3                2013-06-22    109.0          Warner Bros. Pictures
# 4                2017-01-12     80.0   Gaumont British Distributors
# ...                     ...      ...                            ...
# 5453             2013-02-05    101.0              Columbia Pictures
# 5454             2013-08-01     89.0             Paramount Pictures
# 5455             2016-12-30    102.0             Paramount Pictures
# 5456             2012-04-16     88.0    Sony Pictures Entertainment
# 5457             2016-06-07    108.0  Walt Disney Animation Studios
#
#      tomatometer_status  tomatometer_rating  tomatometer_count  \
# 0                Rotten                49.0              149.0
# 1       Certified-Fresh                87.0              142.0
# 2       Certified-Fresh               100.0               54.0
# 3                Rotten                 8.0              149.0
# 4       Certified-Fresh                96.0               51.0
# ...                 ...                 ...                ...
# 5453             Rotten                14.0              132.0
# 5454              Fresh                64.0              138.0
# 5455             Rotten                22.0              232.0
# 5456             Rotten                 4.0               68.0
# 5457    Certified-Fresh                98.0              291.0
#
#      audience_status  audience_rating  audience_count
# 0            Spilled             53.0        254421.0
# 1            Upright             64.0         11574.0
# 2            Upright             97.0        105386.0
# 3            Spilled             37.0        411140.0
# 4            Upright             86.0         23890.0
# ...              ...              ...             ...
# 5453         Spilled             41.0         44713.0
# 5454         Upright             80.0        944800.0
# 5455         Spilled             20.0         41745.0
# 5456         Spilled             33.0         11369.0
# 5457         Upright             92.0        101511.0
#
# [5458 rows x 16 columns]
